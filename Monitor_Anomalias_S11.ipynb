# %% [markdown]
# # 🛡️ Fase 1: Motor de Detección de Anomalías de Comportamiento
# **Analista:** Gustavo Alfonso Maldonado Vallejo
# **Objetivo:** Desarrollar un modelo predictivo para identificar patrones de riesgo y fuga de usuarios (Churn) utilizando técnicas de aprendizaje supervisado y manejo de desequilibrio de clases.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

# Cargar datos
try:
    df = pd.read_csv('datasets/Churn.csv')
    print("Dataset cargado exitosamente.")
except:
    print("Error: Verifica la ruta del archivo en datasets/Churn.csv")
# Out:
# Dataset cargado exitosamente.
